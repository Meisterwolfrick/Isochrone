# %%
# %run MassTracks.ipynb
# %run IsochroneGen.ipynb

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.interpolate import interp1d
from pathlib import Path
import math

# %%
# models = {}
# global models

# %%
# ZAMS = "ZAMS"
# IAMS = "IAMS"
# TAMS = "TAMS"
# RGBTip = "RGBTip"
# sEEP = "sEEP"

# %%
# for (root, dirs, file) in os.walk('./Complete_files_folder/'):
#     for track in file:
#         model =('./Complete_files_folder/' + track)
#         data = np.genfromtxt(model, usecols = range(0,61))
#         models[track] = {}
#         models[track][ZAMS] = MassTrack.get_ZAMS(data)
#         models[track][IAMS] = MassTrack.get_IAMS(data)
#         models[track][TAMS] = MassTrack.get_TAMS(data)
#         models[track][RGBTip] = MassTrack.get_RGBTip(data)
#         models[track][sEEP]= MassTrack.get_sEEPs(data)

# %%
print(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][ZAMS])
# Out:
# [ 4.35580250e+02  6.79419750e+02  1.02786269e-02  9.11333965e-01
#   2.31873781e-01  4.20456444e+00  3.87352602e+00  2.97023816e-01
#   0.00000000e+00  8.84966492e-01  0.00000000e+00  7.25350867e-01
#   1.37932790e-02  9.57799014e+33  1.36267528e+33  1.22701467e+32
#   2.02636351e+34  0.00000000e+00  0.00000000e+00 -2.26521800e+30
#   0.00000000e+00 -9.21436746e-03             nan  7.24746776e+00
#   1.74567200e+00  1.71298556e+01  9.98172962e-01 -2.53076321e+00
#   7.25238432e-01  1.37943616e-02             nan             nan
#              nan  4.00000000e+00  2.04084966e-05  1.45774367e-03
#   3.45851560e-04  1.47485054e-03  0.00000000e+00  6.05998876e-03
#   0.00000000e+00  0.00000000e+00  5.32660781e-18  0.00000000e+00
#   0.00000000e+00  7.20684170e-26  9.40248302e-05  2.41887356e-03
#   2.44187236e-05  6.99263448e-04  0.00000000e+00  6.05968325e-03
#   0.00000000e+00  0.00000000e+00  2.30787999e-17  7.52659779e-11
# ...

# %%
models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][IAMS]
# Out:
# array([ 6.33684211e+02,  7.41368422e+02,  1.44843400e+00,  1.09716528e+00,
#         3.52075613e-01,  3.96416078e+00,  3.85988293e+00,  1.79942588e-01,
#         0.00000000e+00,  8.84966492e-01,  0.00000000e+00,  7.25350867e-01,
#         1.37932790e-02,  5.64951065e+33,  6.04829270e+33,  1.02277771e+33,
#         3.54206462e+34,  0.00000000e+00,  0.00000000e+00, -9.04022867e+31,
#         0.00000000e+00, -1.88137925e-01,             nan,  7.36330089e+00,
#         2.00685933e+00,  1.73400372e+01,  9.96727325e-01, -2.61175536e+00,
#         3.00000000e-01,  1.37943616e-02,             nan,             nan,
#                    nan,  4.00000000e+00,  5.19120103e-07,  2.97702723e-05,
#         6.76279195e-06,  8.48902229e-03,  0.00000000e+00,  3.64849886e-04,
#         0.00000000e+00,  0.00000000e+00,  1.92892742e-18,  0.00000000e+00,
#         0.00000000e+00,  7.20684170e-26,  9.40248302e-05,  2.41887356e-03,
# ...

# %%
models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][TAMS]
# Out:
# array([ 7.41442071e+02,  9.16000000e+02,  1.92083763e+00,  1.25186382e+00,
#         5.30062160e-01,  3.60818769e+00,  3.80956429e+00,  0.00000000e+00,
#         0.00000000e+00,  8.84966492e-01,  7.43411353e-02,  7.25350867e-01,
#         1.37932790e-02,  3.65253539e+33,  2.83290340e+33,  3.43708361e+32,
#         6.57564954e+34,  0.00000000e+00,  0.00000000e+00, -3.97388039e+33,
#         0.00000000e+00, -5.79184668e+00,  2.29064540e-02,  7.44111886e+00,
#         3.16272922e+00,  1.84177887e+01,  9.99439696e-01, -2.98451357e-01,
#         1.00000000e-11,  1.37943802e-02,  2.72493468e-01,  4.24150958e-01,
#         1.99355640e-06,  0.00000000e+00,  0.00000000e+00,  5.52100440e-05,
#         1.26188999e-05,  8.69098855e-03,  0.00000000e+00,  9.29068567e-05,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.20684170e-26,  9.40248302e-05,  2.41887356e-03,
# ...

# %%
models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][RGBTip]
# Out:
# array([ 8.22500000e+03,  1.91400000e+03,  2.03774279e+00,  3.29748746e+00,
#         2.05060484e+00,  5.67102320e-01,  3.56069886e+00,  0.00000000e+00,
#         1.23961732e+00,  7.00305493e-03,  4.57075178e-01,  7.05560952e-01,
#         1.37942148e-02,  1.99394713e+33,  9.80322728e+31,  1.64069859e+32,
#         7.55302307e+36,  2.11423675e+36, -3.58812652e+33, -2.04633586e+36,
#         1.58794100e+33, -2.68506439e+01,  3.87303061e-03,  7.90446832e+00,
#         5.91426157e+00,  2.23133102e+01,  9.99994915e-01,  1.79689823e+01,
#         0.00000000e+00,  1.39378355e-02,  4.57268683e-01,  7.04374171e-04,
#         6.41505248e+00, -2.79977906e+00,  0.00000000e+00,  1.98665303e-04,
#         0.00000000e+00,  8.68955027e-03,  0.00000000e+00,  9.29068567e-05,
#         0.00000000e+00,  1.84922693e-06,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.20684170e-26,  5.13833055e-04,  1.59751409e-03,
# ...

# %%
print(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][sEEP])
# Out:
# [[4.36000000e+02 6.79000000e+02 1.02986963e-02 ... 1.74900000e+01
#   2.29300000e-02 1.14900000e-06]
#  [4.36583174e+02 6.78416826e+02 1.03276948e-02 ... 1.74666731e+01
#   2.28658509e-02 1.14375144e-06]
#  [4.37173010e+02 6.77826990e+02 1.03573687e-02 ... 1.74430796e+01
#   2.28009689e-02 1.13896194e-06]
#  ...
#  [6.17955526e+02 7.17911052e+02 1.17276148e+00 ... 2.11026818e+01
#   3.26622503e-02 1.03824527e-06]
#  [6.17955526e+02 7.17911052e+02 1.17276148e+00 ... 2.11026818e+01
#   3.26622503e-02 1.03824527e-06]
#  [6.17955526e+02 7.17911052e+02 1.17276148e+00 ... 2.11026818e+01
#   3.26622503e-02 1.03824527e-06]]

# %%
model =('./Complete_files_folder/' + 'm1700_GAS07_p000_p0_y26_mlt2.040.ntrk')
data = np.genfromtxt(model, usecols = range(0,61))

# %%
plt.plot((10**(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][sEEP][:,6])),models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][sEEP][:,3], color='blue', marker='o')
plt.plot((10**(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][ZAMS][6])),models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][ZAMS][3], color='red', marker='o')
plt.plot((10**(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][IAMS][6])),models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][IAMS][3], color='red', marker='o')
plt.plot((10**(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][TAMS][6])),models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][TAMS][3], color='red', marker='o')
plt.plot((10**(models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][RGBTip][6])),models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][RGBTip][3], color='red', marker='o')
plt.plot((10**(data[:,6])), data[:,3])

# %%
#due to issues with age range in data, interpolating the sEEPs errors
seeps = IsochroneInterpolation.interpolate_sEEP(0.05)
plt.plot((10**(Isochrone.interpolate_ZAMS(0.05)[6])),Isochrone.interpolate_ZAMS(0.05)[3], color='red', marker='o')
plt.plot((10**(seeps[:,6])), seeps[:,3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #due to issues with age range in data interpolating the sEEPs errors
# ----> 2 seeps = IsochroneInterpolation.interpolate_sEEP(0.05)
#       3 plt.plot((10**(Isochrone.interpolate_ZAMS(0.05)[6])),Isochrone.interpolate_ZAMS(0.05)[3], color='red', marker='o')
#       4 plt.plot((10**(seeps[:,6])), seeps[:,3])
#
# File ~\AppData\Local\Temp\ipykernel_11784\840196114.py:60, in IsochroneInterpolation.interpolate_sEEP(age)
#      58         sEEParray = np.row_stack((sEEParray, models[track][sEEP][n,:]))
#      59     int_curve = interp1d(sEEParray[:,2], sEEParray[:,0:], axis=0)
# ---> 60     IsochronesEEP = np.array(int_curve(age))
#      61     allsEEParray = np.row_stack((allsEEParray, IsochronesEEP))
#      62 n += 1
#
# ...

# %%
models['m1700_GAS07_p000_p0_y26_mlt2.040.ntrk'][ZAMS][6]
